# %%
import numpy as np
import pandas as pd

# %%
casos = pd.read_csv("CasosActivosPorComuna.csv", index_col="Region")
casos.head()
# Out:
#                     Codigo region                          Comuna  \
# Region
# Arica y Parinacota             15                           Arica
# Arica y Parinacota             15                       Camarones
# Arica y Parinacota             15                   General Lagos
# Arica y Parinacota             15                           Putre
# Arica y Parinacota             15  Desconocido Arica y Parinacota
#
#                     Codigo comuna  Poblacion  2020-04-13  2020-04-15  \
# Region
# Arica y Parinacota        15101.0   247552.0        88.0        80.0
# Arica y Parinacota        15102.0     1233.0         0.0         0.0
# Arica y Parinacota        15202.0      810.0         0.0         0.0
# Arica y Parinacota        15201.0     2515.0         0.0         0.0
# Arica y Parinacota            NaN        NaN         NaN         NaN
#
#                     2020-04-17  2020-04-20  2020-04-24  2020-04-27  ...  \
# ...

# %%
casos = casos.drop(columns=["Codigo region", "Comuna", "Codigo comuna", "Poblacion"])
casos = casos.groupby("Region").sum()
casos = casos.transpose()
casos = casos.loc['2020-07-01':'2021-07-01']
casos.head()
# Out:
# Region      Antofagasta  Arica y Parinacota  Atacama  Aysen  Biobio  Coquimbo  \
# 2020-07-01       3744.0               814.0    764.0   30.0  4368.0    1602.0
# 2020-07-05       4038.0               992.0    738.0   28.0  3886.0    1688.0
# 2020-07-10       3950.0              1182.0    782.0   12.0  3312.0    1830.0
# 2020-07-13       4046.0              1362.0    944.0   24.0  3304.0    1846.0
# 2020-07-17       3556.0              1696.0    816.0   46.0  3056.0    1844.0
#
# Region      Del Libertador General Bernardo O’Higgins  La Araucania  \
# 2020-07-01                                     5218.0         604.0
# 2020-07-05                                     4914.0         610.0
# 2020-07-10                                     4318.0         516.0
# 2020-07-13                                     4192.0         478.0
# 2020-07-17                                     3606.0         460.0
#
# Region      Los Lagos  Los Rios  Magallanes y la Antartica   Maule  \
# ...

# %%
paso = pd.read_csv("paso_a_paso.csv", index_col="region_residencia")
paso.head()
# Out:
#                     codigo_region  codigo_comuna comuna_residencia    zona  \
# region_residencia
# Arica y Parinacota             15          15101             Arica   Rural
# Arica y Parinacota             15          15101             Arica  Urbana
# Arica y Parinacota             15          15102         Camarones   Total
# Arica y Parinacota             15          15202     General Lagos   Total
# Arica y Parinacota             15          15201             Putre   Total
#
#                     2020-07-28  2020-07-29  2020-07-30  2020-07-31  \
# region_residencia
# Arica y Parinacota           3           3           3           3
# Arica y Parinacota           1           1           1           1
# Arica y Parinacota           3           3           3           3
# Arica y Parinacota           3           3           3           3
# Arica y Parinacota           3           3           3           3
#
# ...

# %%
paso = paso.drop(columns=["codigo_comuna", "comuna_residencia", "zona", "codigo_region"])
paso = paso.groupby("region_residencia").max().transpose()
paso.head()
# Out:
# region_residencia  Antofagasta  Araucanía  Arica y Parinacota  Atacama  Aysén  \
# 2020-07-28                   3          4                   3        3      4
# 2020-07-29                   3          4                   3        3      4
# 2020-07-30                   3          4                   3        3      4
# 2020-07-31                   3          4                   3        3      4
# 2020-08-01                   3          4                   3        3      4
#
# region_residencia  Biobío  Coquimbo  Los Lagos  Los Ríos  Magallanes  Maule  \
# 2020-07-28              3         3          3         4           3      3
# 2020-07-29              3         3          3         4           3      3
# 2020-07-30              3         3          3         4           3      3
# 2020-07-31              3         3          3         4           3      3
# 2020-08-01              3         3          3         4           3      3
#
# ...

# %%
ventas = pd.read_excel("ventas_por_region.xlsx", index_col="Mes y año")
ventas.drop('Total', axis=1)
ventas.head()
# Out:
#             Arica y Parinacota  Tarapacá  Antofagasta  Atacama  Coquimbo  \
# Mes y año
# 2014-01-01                5088      9555        31348    14808     34648
# 2014-02-01                5006      9414        30347    14552     36790
# 2014-03-01                5893     10351        36240    15365     33562
# 2014-04-01                5477      9127        34558    14677     31575
# 2014-05-01                5618      9798        35406    15166     32961
#
#             Valparaíso  Metropolitana  O'Higgins  Maule  Ñuble  Biobío  \
# Mes y año
# 2014-01-01       76094         257437      32094  30597  12692   52839
# 2014-02-01       78423         244038      32731  31586  13226   53136
# 2014-03-01       77747         315990      36944  33867  12970   59967
# 2014-04-01       73683         293688      34706  31727  12206   56130
# 2014-05-01       74167         307467      35402  32975  12601   59511
#
#             La Araucanía  Los Ríos  Los Lagos  Aysén  Magallanes   Total
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
fig, ax = plt.subplots(tight_layout=True,figsize=(12,7))
casos.plot(ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(tight_layout=True,figsize=(12,7))
fmt_month = mdates.MonthLocator()
ax.xaxis.set_major_locator(fmt_month)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax.set_xlabel('Fecha')
ax.set_ylabel('Etapa Plan Paso a Paso')
paso.plot(ax=ax)
plt.show()
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots(tight_layout=True,figsize=(12,7))
ax.set_xlabel('Fecha')
ax.set_ylabel('Millones de Pesos')
ventas.loc['2020-07-01':'2021-07-01'].plot(ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(tight_layout=True,figsize=(12,7))
ax.set_xlabel('Fecha')
ax.set_ylabel('Millones de Pesos')
ventas["Total"].loc['2020-07-01':'2021-05-01'].plot(ax=ax)
plt.show()
